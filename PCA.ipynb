# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('engine_failure_dataset.csv')
df.head(10)
# Out:
#             Time_Stamp  Temperature          RPM  Fuel_Efficiency  \
# 0  2024-12-24 10:00:00    60.308585  3426.827588        20.445472
# 1  2024-12-24 10:05:00   112.705055  2949.758424        23.083947
# 2  2024-12-24 10:10:00   108.670976  1817.971040        20.555326
# 3  2024-12-24 10:15:00   107.114691  2730.660539        23.226431
# 4  2024-12-24 10:20:00   118.075814  1854.488677        21.148226
# 5  2024-12-24 10:25:00    78.157210  2324.480476        16.627448
# 6  2024-12-24 10:30:00   114.084534  1128.439288        26.561841
# 7  2024-12-24 10:35:00   108.399936  2424.950038        24.155412
# 8  2024-12-24 10:40:00    84.485655  1662.500402        25.535557
# 9  2024-12-24 10:45:00    73.573443  2815.996636        28.375972
#
#    Vibration_X  Vibration_Y  Vibration_Z      Torque  Power_Output  \
# 0     0.874657     0.005686     0.529798  107.877658     23.367684
# 1     0.696461     0.391779     0.124336   60.351655     57.941022
# 2     0.495276     0.189714     0.886417  110.986564     47.732998
# 3     0.986206     0.983202     0.468114   77.416793     44.112039
# 4     0.710810     0.101139     0.481034  100.475881     80.681972
# 5     0.484482     0.242013     0.437504   91.495077     86.981820
# 6     0.261974     0.715318     0.280295  123.156877     82.441668
# 7     0.432189     0.761122     0.869901  152.349026     80.371809
# 8     0.140342     0.341326     0.172818   90.763384     27.128899
# 9     0.384356     0.034136     0.230663  127.348256     31.823300
#
#    Fault_Condition Operational_Mode
# 0                2             Idle
# 1                3         Cruising
# 2                2         Cruising
# 3                2         Cruising
# 4                2         Cruising
# 5                0         Cruising
# 6                1         Cruising
# 7                1             Idle
# 8                0             Idle
# 9                1       Heavy Load

# %%
df = df.drop('Time_Stamp', axis=1)

# %%
# Get dimensions
rows = df.shape[0]
attributes = df.shape[1]

print(f"Number of rows: {rows}")
print(f"Number of attributes: {attributes}")
df.shape
# Out:
# Number of rows: 1000
# Number of attributes: 10
# (1000, 10)

# %%
numeric_count = len(df.select_dtypes(include=['number']).columns)

# Count categorical attributes (objects, strings, categories)
categorical_count = len(df.select_dtypes(exclude=['number']).columns)

print(f"Numeric attributes: {numeric_count}")
print(f"Categorical attributes: {categorical_count}")
# Out:
# Numeric attributes: 9
# Categorical attributes: 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Temperature       1000 non-null   float64
#  1   RPM               1000 non-null   float64
#  2   Fuel_Efficiency   1000 non-null   float64
#  3   Vibration_X       1000 non-null   float64
#  4   Vibration_Y       1000 non-null   float64
#  5   Vibration_Z       1000 non-null   float64
#  6   Torque            1000 non-null   float64
#  7   Power_Output      1000 non-null   float64
#  8   Fault_Condition   1000 non-null   int64
#  9   Operational_Mode  1000 non-null   object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 74.3+ KB

# %%
import micropip

await micropip.install("seaborn")

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])
print(numeric_df)
# Out:
#      Temperature          RPM  Fuel_Efficiency  Vibration_X  Vibration_Y  \
# 0      60.308585  3426.827588        20.445472     0.874657     0.005686
# 1     112.705055  2949.758424        23.083947     0.696461     0.391779
# 2     108.670976  1817.971040        20.555326     0.495276     0.189714
# 3     107.114691  2730.660539        23.226431     0.986206     0.983202
# 4     118.075814  1854.488677        21.148226     0.710810     0.101139
# ..           ...          ...              ...          ...          ...
# 995    88.231211  1477.774501        23.749532     0.827987     0.664745
# 996   105.241946  1617.745044        16.166110     0.753548     0.797969
# 997   119.066775  2473.669785        17.657404     0.982960     0.699409
# 998    90.620157  2297.744136        17.479882     0.686213     0.875040
# 999    93.144406  2511.308863        17.597145     0.950341     0.340887
#
#      Vibration_Z      Torque  Power_Output  Fault_Condition
# 0       0.529798  107.877658     23.367684              2.0
# 1       0.124336   60.351655     57.941022              3.0
# 2       0.886417  110.986564     47.732998              2.0
# 3       0.468114   77.416793     44.112039              2.0
# 4       0.481034  100.475881     80.681972              2.0
# ..           ...         ...           ...              ...
# 995     0.625331  178.466184     41.494154              3.0
# 996     0.618335  154.586204     52.987240              0.0
# 997     0.804165  164.138685     55.994142              3.0
# 998     0.370690   78.687527     38.729023              1.0
# 999     0.072738  178.572291     83.769023              0.0
#
# [1000 rows x 9 columns]

# %%
numeric_df = numeric_df.drop('Fault_Condition', axis=1)

# %%
# Standardize data
scaler = StandardScaler()

scaled_data = scaler.fit_transform(numeric_df)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

principal_components = pca.fit_transform(scaled_data)

# %%
pca = PCA(n_components=2)

principal_components = pca.fit_transform(scaled_data)

# Create PCA dataframe
pca_df = pd.DataFrame(
    principal_components,
    columns=['PC1', 'PC2']
)

# %%
print(pca_df)
# Out:
#           PC1       PC2
# 0   -1.413010  0.004455
# 1   -0.139221 -1.434106
# 2    1.288087  1.070248
# 3   -1.132125 -0.394159
# 4    1.986985 -0.922897
# ..        ...       ...
# 995  0.234709  0.434749
# 996  0.947965  0.993583
# 997  1.093240  0.607826
# 998 -0.952185  0.556230
# 999  1.230593 -1.552773
#
# [1000 rows x 2 columns]

# %%
# Explained variance
print("Explained Variance Ratio:")
print(pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio:
# [0.14617082 0.1373592 ]

# %%
# Plot PCA
plt.figure(figsize=(7,5))

plt.scatter(
    pca_df['PC1'],
    pca_df['PC2']
)

plt.xlabel("PC1")
plt.ylabel("PC2")

plt.title("PCA Projection")

plt.show()
