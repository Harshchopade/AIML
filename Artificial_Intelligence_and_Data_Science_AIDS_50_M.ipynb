# %% [markdown]
# # SE VSE-282-MEC: Data Science & AIML PRACTICAL Exam (50 Marks)
#
# IMPORTANT RENAME YOUR FILE WITH PRN NO

# %% [markdown]
# # Student Detail
# Name :
#
# Roll no :
#
# Div/Batch :
#
# Class :
#
# Prn No/ Exam seat no:

# %% [markdown]
# # 1. Problem Identification & Data Loading/ analyze (10 Marks)

# %% [markdown]
# ### 1) Problem Statement (2 marks)

# %% [markdown]
# hint: Open the data set and write about size of data set, supervsied learning or unsupervised learning, regression problem or classification problem.

# %% [markdown]
# ### 2) Import Necessary Libraries (2 marks)¶

# %% [markdown]
# ### 3) Data Analysis (6 marks)¶

# %% [markdown]
# ##### 3.1) Upload Data & analyze top and bottom 15 rows of data
# hint 1 : if file is csv format use pd.read_csv if file is xslx format then use pd.read_excel
#
# hint 2: head and tail (to analyze top and bottom rows)

# %% [markdown]
# ##### 3.2) Shape of Data
# hint(shape)

# %% [markdown]
# ##### 3.3) Observe Data types & null values in each features
# hint(info)

# %% [markdown]
# ##### 3.4) Check 5 point summary of data
# hint(describe)

# %% [markdown]
# ##### 3.5) Key Point Indicators: Strong insight from data analysis

# %% [markdown]
# ### 4) Visualize & Analyze Data (15 Marks)
# #### important: write insight after every visualization graph

# %% [markdown]
# ##### 4.1 Univariate Analysis

# %% [markdown]
# 4.2 Bivariate Analysis

# %% [markdown]
# ##### 4.3 Multivariate Analysis

# %% [markdown]
# ### 5) Data Cleaning / Processing  (10 Marks)
# Hint: After each data processing step check the shape of data. Also try to explain why you are doing this and whats happening

# %% [markdown]
# #### 5.1) FInd and Treat Null Values with suitable methodolgy

# %% [markdown]
#  5.2) Drop feature less then 0.2 standard deviation

# %% [markdown]
# #### 5.3) Data cleaning process of your choice

# %% [markdown]
# #### Insight of Data Cleaning & Processing
# Hint: check shape of data after 5.1, 5.2 and 5.3 and write the insight

# %% [markdown]
# ### 6) Select Features and perfrom Train- Test Split on data for Modeling (2.5 Marks)

# %% [markdown]
# ### 7) Stadardize / Normalize Data (2.5 Marks)
# Hint: explain need of Standardization and Normalization. why we need to standardize or nor normalize data. write in short. .

# %% [markdown]
# ### 8) Run Machine Learning Model For Classification/ Regression (2.5 Marks)
# Hint: Try to tune model or explain hyperparameter tuning of any model.  Also explain when and why to do Hyperparameter tuning.

# %% [markdown]
# ### 9) Evaluate Model Performance and Conclude the experiment (7.5 Marks)
# Hint: Write in your own words
